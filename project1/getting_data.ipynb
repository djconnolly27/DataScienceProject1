# %%
import pandas as pd
nsduh_2002 = pd.read_stata('NSDUH_2002.DTA')
nsduh_2002.head()
# Out:
#    QUESTID2    filedate  cigever              cigofrsm              cigwilyr  \
# 0  02000024  09/07/2018  1 - Yes  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 1  02000239  09/07/2018  1 - Yes  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 2  02000248  09/07/2018  1 - Yes  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 3  02000471  09/07/2018  1 - Yes  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 4  02000630  09/07/2018  1 - Yes  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
#
#   cigtry                  cigyfu                cigmfu  \
# 0     15  9999 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 1     10  9999 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 2     18  9999 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 3     14  9999 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 4     13  9999 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
#
#                                               cigrec  \
# 0                        1 - Within the past 30 days
# 1  2 - More than 30 days ago but within the past ...
# ...

# %%
nsduh_2003 = pd.read_stata('NSDUH_2003.DTA')

# %%
nsduh_2004 = pd.read_stata('NSDUH_2004.DTA')

# %%
nsduh_2005 = pd.read_stata('NSDUH_2005.DTA')

# %%
nsduh_2006 = pd.read_stata('NSDUH_2006.DTA')

# %%
nsduh_2007 = pd.read_stata('NSDUH_2007.DTA')

# %%
nsduh_2008 = pd.read_stata('NSDUH_2008.DTA')

# %%
nsduh_2009 = pd.read_stata('NSDUH_2009.DTA')

# %%
nsduh_2010 = pd.read_stata('NSDUH_2010.DTA')

# %%
nsduh_2011 = pd.read_stata('NSDUH_2011.DTA')

# %%
nsduh_2012 = pd.read_stata('NSDUH_2012.DTA')

# %%
nsduh_2013 = pd.read_stata('NSDUH_2013.DTA')

# %%
nsduh_2014 = pd.read_stata('NSDUH_2014.DTA')

# %%
nsduh_2015 = pd.read_stata('NSDUH_2015.DTA')

# %%
nsduh_2016 = pd.read_stata('NSDUH_2016.DTA')

# %%
nsduh_2017 = pd.read_stata('NSDUH_2017.DTA')

# %%
nsduh_2002['year'] = 2002
nsduh_2003['year'] = 2003
nsduh_2004['year'] = 2004
nsduh_2005['year'] = 2005
nsduh_2006['year'] = 2006
nsduh_2007['year'] = 2007
nsduh_2008['year'] = 2008
nsduh_2009['year'] = 2009
nsduh_2010['year'] = 2010
nsduh_2011['year'] = 2011
nsduh_2012['year'] = 2012
nsduh_2013['year'] = 2013
nsduh_2014['year'] = 2014
nsduh_2015['year'] = 2015
nsduh_2016['year'] = 2016
nsduh_2017['year'] = 2017

nsduh_2002.to_pickle('nsduh_2002.pkl')
nsduh_2003.to_pickle('nsduh_2003.pkl')
nsduh_2004.to_pickle('nsduh_2004.pkl')
nsduh_2005.to_pickle('nsduh_2005.pkl')
nsduh_2006.to_pickle('nsduh_2006.pkl')
nsduh_2007.to_pickle('nsduh_2007.pkl')
nsduh_2008.to_pickle('nsduh_2008.pkl')
nsduh_2009.to_pickle('nsduh_2009.pkl')
nsduh_2010.to_pickle('nsduh_2010.pkl')
nsduh_2011.to_pickle('nsduh_2011.pkl')
nsduh_2012.to_pickle('nsduh_2012.pkl')
nsduh_2013.to_pickle('nsduh_2013.pkl')
nsduh_2014.to_pickle('nsduh_2014.pkl')
nsduh_2015.to_pickle('nsduh_2015.pkl')
nsduh_2016.to_pickle('nsduh_2016.pkl')
nsduh_2017.to_pickle('nsduh_2017.pkl')

# %%
import pandas as pd
nsduh_2002 = pd.read_pickle('nsduh_2002.pkl')
nsduh_2003 = pd.read_pickle('nsduh_2003.pkl')
nsduh_2004 = pd.read_pickle('nsduh_2004.pkl')
nsduh_2005 = pd.read_pickle('nsduh_2005.pkl')
nsduh_2006 = pd.read_pickle('nsduh_2006.pkl')
nsduh_2007 = pd.read_pickle('nsduh_2007.pkl')
nsduh_2008 = pd.read_pickle('nsduh_2008.pkl')
nsduh_2009 = pd.read_pickle('nsduh_2009.pkl')
nsduh_2010 = pd.read_pickle('nsduh_2010.pkl')
nsduh_2011 = pd.read_pickle('nsduh_2011.pkl')
nsduh_2012 = pd.read_pickle('nsduh_2012.pkl')
nsduh_2013 = pd.read_pickle('nsduh_2013.pkl')
nsduh_2014 = pd.read_pickle('nsduh_2014.pkl')
nsduh_2015 = pd.read_pickle('nsduh_2015.pkl')
nsduh_2016 = pd.read_pickle('nsduh_2016.pkl')
nsduh_2017 = pd.read_pickle('nsduh_2017.pkl')

# %%
n2_3 = pd.concat([nsduh_2002, nsduh_2003], ignore_index=True, sort=False)
n2_3.head()
# Out:
#    QUESTID2    filedate  cigever              cigofrsm              cigwilyr  \
# 0  02000024  09/07/2018  1 - Yes  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 1  02000239  09/07/2018  1 - Yes  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 2  02000248  09/07/2018  1 - Yes  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 3  02000471  09/07/2018  1 - Yes  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 4  02000630  09/07/2018  1 - Yes  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
#
#   cigtry                  cigyfu                cigmfu  \
# 0     15  9999 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 1     10  9999 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 2     18  9999 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 3     14  9999 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 4     13  9999 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
#
#                                               cigrec  \
# 0                        1 - Within the past 30 days
# 1  2 - More than 30 days ago but within the past ...
# ...

# %%
nsduh2_4 = pd.concat([n2_3, nsduh_2004], ignore_index=True, sort=False)

# %%
nsduh2_4.to_pickle('nsduh_2002_2004.pkl')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-11-6090a7cff487> in <module>
# ----> 1 nsduh2_4.to_pickle('nsduh_2002_2004.pkl')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_pickle(self, path, compression, protocol)
#    2190         from pandas.io.pickle import to_pickle
#    2191         return to_pickle(self, path, compression=compression,
# -> 2192                          protocol=protocol)
#    2193
#    2194     def to_clipboard(self, excel=True, sep=None, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/pickle.py in to_pickle(obj, path, compression, protocol)
#      75         protocol = pkl.HIGHEST_PROTOCOL
#      76     try:
# ---> 77         f.write(pkl.dumps(obj, protocol=protocol))
#      78     finally:
#      79         for _f in fh:
#
# MemoryError:

# %%
nsduh2_5 = pd.concat([nsduh2_4, nsduh_2005], ignore_index=True, sort=False)

# %%
nsduh2_5.to_pickle('nsduh_2002_2005.pkl')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-10-37a4205f7ef2> in <module>
# ----> 1 nsduh2_5.to_pickle('nsduh_2002_2005.pkl')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_pickle(self, path, compression, protocol)
#    2190         from pandas.io.pickle import to_pickle
#    2191         return to_pickle(self, path, compression=compression,
# -> 2192                          protocol=protocol)
#    2193
#    2194     def to_clipboard(self, excel=True, sep=None, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/pickle.py in to_pickle(obj, path, compression, protocol)
#      75         protocol = pkl.HIGHEST_PROTOCOL
#      76     try:
# ---> 77         f.write(pkl.dumps(obj, protocol=protocol))
#      78     finally:
#      79         for _f in fh:
#
# MemoryError:

# %%
nsduh2_6 = pd.concat([nsduh2_5, nsduh_2006], ignore_index=True, sort=False)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-7-45fc398df92a> in <module>
# ----> 1 nsduh2_6 = pd.concat([nsduh2_5, nsduh_2006], ignore_index=True, sort=False)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     223                        keys=keys, levels=levels, names=names,
#     224                        verify_integrity=verify_integrity,
# --> 225                        copy=copy, sort=sort)
#     226     return op.get_result()
#     227
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     287
#     288             # consolidate
# --> 289             obj._consolidate(inplace=True)
# ...

# %%
nsduh2_7 = pd.concat([nsduh2_6, nsduh_2007], ignore_index=True, sort=False)

# %%
nsduh2_8 = pd.concat([nsduh2_7, nsduh_2008], ignore_index=True, sort=False)

# %%
nsduh2_9 = pd.concat([nsduh2_8, nsduh_2009], ignore_index=True, sort=False)

# %%
nsduh2_10 = pd.concat([nsduh2_9, nsduh_2010], ignore_index=True, sort=False)

# %%
nsduh2_11 = pd.concat([nsduh2_10, nsduh_2011], ignore_index=True, sort=False)

# %%
nsduh2_12 = pd.concat([nsduh2_11, nsduh_2012], ignore_index=True, sort=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-7ee8c3122e8d> in <module>
# ----> 1 nsduh2_8.head()
#
# NameError: name 'nsduh2_8' is not defined

# %%
nsduh2_13 = pd.concat([nsduh2_12, nsduh_2013], ignore_index=True, sort=False)

# %%
nsduh2_14 = pd.concat([nsduh2_13, nsduh_2014], ignore_index=True, sort=False)

# %%
nsduh2_15 = pd.concat([nsduh2_14, nsduh_2015], ignore_index=True, sort=False)

# %%
nsduh2_16 = pd.concat([nsduh2_15, nsduh_2016], ignore_index=True, sort=False)

# %%
nsduh2_17 = pd.concat([nsduh2_16, nsduh_2017], ignore_index=True, sort=False)

# %%
nsduh2_17.to_pickle('nsduh_2002_2017.pkl')

# %%
nsduh02_17['year']
# Out:
# 0         2002
# 1         2002
# 2         2002
# 3         2002
# 4         2002
# 5         2002
# 6         2002
# 7         2002
# 8         2002
# 9         2002
# 10        2002
# 11        2002
# 12        2002
# 13        2002
# 14        2002
# 15        2002
# 16        2002
# 17        2002
# 18        2002
# 19        2002
# 20        2002
# 21        2002
# 22        2002
# 23        2002
# 24        2002
# 25        2002
# 26        2002
# 27        2002
# 28        2002
# 29        2002
#           ...
# 164881    2004
# 164882    2004
# 164883    2004
# 164884    2004
# 164885    2004
# 164886    2004
# 164887    2004
# 164888    2004
# 164889    2004
# 164890    2004
# 164891    2004
# 164892    2004
# 164893    2004
# 164894    2004
# 164895    2004
# 164896    2004
# 164897    2004
# 164898    2004
# 164899    2004
# 164900    2004
# 164901    2004
# 164902    2004
# 164903    2004
# 164904    2004
# 164905    2004
# 164906    2004
# 164907    2004
# ...

# %%
nsduh_2002.loc[:, 'cigever': 'cigmfu']
# Out:
#        cigever              cigofrsm              cigwilyr  \
# 0      1 - Yes  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 1      1 - Yes  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 2      1 - Yes  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 3      1 - Yes  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 4      1 - Yes  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 5      1 - Yes  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 6       2 - No  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 7      1 - Yes  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 8      1 - Yes  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 9       2 - No    4 - Definitely Not    4 - Definitely Not
# 10     1 - Yes  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 11     1 - Yes  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 12      2 - No  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 13     1 - Yes  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 14     1 - Yes  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# ...

# %%
nsduh_2002[['cigever','cigmfu']]
# Out:
#        cigever                            cigmfu
# 0      1 - Yes              99 - LEGITIMATE SKIP
# 1      1 - Yes              99 - LEGITIMATE SKIP
# 2      1 - Yes              99 - LEGITIMATE SKIP
# 3      1 - Yes              99 - LEGITIMATE SKIP
# 4      1 - Yes              99 - LEGITIMATE SKIP
# 5      1 - Yes              99 - LEGITIMATE SKIP
# 6       2 - No        91 - NEVER USED CIGARETTES
# 7      1 - Yes                     9 - September
# 8      1 - Yes              99 - LEGITIMATE SKIP
# 9       2 - No        91 - NEVER USED CIGARETTES
# 10     1 - Yes              99 - LEGITIMATE SKIP
# 11     1 - Yes              99 - LEGITIMATE SKIP
# 12      2 - No        91 - NEVER USED CIGARETTES
# 13     1 - Yes              99 - LEGITIMATE SKIP
# 14     1 - Yes                       1 - January
# 15     1 - Yes              99 - LEGITIMATE SKIP
# 16     1 - Yes              99 - LEGITIMATE SKIP
# 17     1 - Yes              99 - LEGITIMATE SKIP
# ...
